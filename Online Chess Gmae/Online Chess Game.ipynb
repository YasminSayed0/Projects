# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cg=pd.read_csv('chess_games.csv')
cg
# Out:
#        game_id  rated  turns victory_status winner time_increment  \
# 0            1  False     13    Out of Time  White           15+2
# 1            2   True     16         Resign  Black           5+10
# 2            3   True     61           Mate  White           5+10
# 3            4   True     61           Mate  White           20+0
# 4            5   True     95           Mate  White           30+3
# ...        ...    ...    ...            ...    ...            ...
# 20053    20054   True     24         Resign  White          10+10
# 20054    20055   True     82           Mate  Black           10+0
# 20055    20056   True     35           Mate  White           10+0
# 20056    20057   True    109         Resign  White           10+0
# 20057    20058   True     78           Mate  Black           10+0
#
#             white_id  white_rating            black_id  black_rating  \
# 0           bourgris          1500                a-00          1191
# ...

# %%
cg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
#  11  opening_code       20058 non-null  object
#  12  opening_moves      20058 non-null  int64
#  13  opening_fullname   20058 non-null  object
#  14  opening_shortname  20058 non-null  object
#  15  opening_response   1207 non-null   object
# ...

# %%
pd.DataFrame({'count':cg.shape[0],
               'null%':cg.isnull().mean() *100,
               'null':cg.isnull().sum(),
               'cardinality':cg.nunique()
    
    
})
# Out:
#                    count      null%   null  cardinality
# game_id            20058   0.000000      0        20058
# rated              20058   0.000000      0            2
# turns              20058   0.000000      0          211
# victory_status     20058   0.000000      0            4
# winner             20058   0.000000      0            3
# time_increment     20058   0.000000      0          400
# white_id           20058   0.000000      0         9438
# white_rating       20058   0.000000      0         1516
# black_id           20058   0.000000      0         9331
# black_rating       20058   0.000000      0         1521
# moves              20058   0.000000      0        18920
# opening_code       20058   0.000000      0          365
# opening_moves      20058   0.000000      0           23
# opening_fullname   20058   0.000000      0         1477
# opening_shortname  20058   0.000000      0          128
# opening_response   20058  93.982451  18851            3
# ...

# %%
cg.duplicated().any()
# Out:
# False

# %%
percentage_cg = (cg['winner'].value_counts() / len(cg)) * 100
plt.figure(figsize=(10, 6))  
sns.barplot(x=percentage_cg.index, y=percentage_cg.values)

for index, value in enumerate(percentage_cg):
    plt.text(index, value + 0.5, f'{value:.2f}%',ha='center')
    
plt.xlabel('Winner')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Winner')

plt.tight_layout()
plt.show()

# %%
purpose_counts = cg['rated'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(purpose_counts, labels=purpose_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution Of Rated')
plt.axis('equal')  
plt.show()

# %%
percentage_cg = (cg['victory_status'].value_counts() / len(cg)) * 100
plt.figure(figsize=(10, 6))  
sns.barplot(x=percentage_cg.index, y=percentage_cg.values)

for index, value in enumerate(percentage_cg):
    plt.text(index, value + 0.5, f'{value:.2f}%',ha='center')
    
plt.xlabel('Victory Status')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Victory Status')

plt.tight_layout()
plt.show()

# %%
black=cg[cg['winner']=='Black']

# %%
percentage_cg = (black['opening_code'].value_counts() / len(black)) * 100
top_12 = percentage_cg.nlargest(20)

plt.figure(figsize=(11, 7))  
sns.barplot(x=top_12.index, y=top_12.values)

for index, value in enumerate(top_12):
        plt.text(index, value, f'{value:.2f}%', ha='center',va='bottom')     
plt.xlabel('Opening Code')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 20 Opening Code(balck)')

plt.tight_layout()
plt.show()

# %%
white=cg[cg['winner']=='White']

# %%
percentage_cg = (white['opening_code'].value_counts() / len(white)) * 100
top_12 = percentage_cg.nlargest(20)

plt.figure(figsize=(11, 7))  
sns.barplot(x=top_12.index, y=top_12.values)

for index, value in enumerate(top_12):
        plt.text(index, value, f'{value:.2f}%', ha='center',va='bottom')     
plt.xlabel('Opening Code')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 20 Opening Coed(White)')

plt.tight_layout()
plt.show()

# %%
percentage_cg = (cg['white_id'].value_counts() / len(cg)) * 100
top_12 = percentage_cg.nlargest(20)

plt.figure(figsize=(12, 8))  
sns.barplot(x=top_12.index, y=top_12.values)

for index, value in enumerate(top_12):
        plt.text(index, value , f'{value:.2f}%', ha='center')  # تحديد محاذاة النص وتدويره    
plt.xlabel('White id')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 20(White id)')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %%
sum_ratings_white = cg['white_rating'].sum()
sum_ratings_black = cg['black_rating'].sum()

total_sum = sum_ratings_white + sum_ratings_black

percentage_white = (sum_ratings_white / total_sum) * 100
percentage_black = (sum_ratings_black / total_sum) * 100

plt.figure(figsize=(8, 6))
sns.barplot(x=['white', 'black'], y=[sum_ratings_white, sum_ratings_black])
plt.xlabel('Column')
plt.ylabel('Sum of Ratings')
plt.title('Sum of Ratings for Each Column')

plt.text(0, sum_ratings_white, f'{percentage_white:.2f}%', ha='center', va='bottom')
plt.text(1, sum_ratings_black, f'{percentage_black:.2f}%', ha='center', va='bottom')

plt.show()

# %%
percentage_cg = (cg['black_id'].value_counts() / len(cg)) * 100
top_12 = percentage_cg.nlargest(20)

plt.figure(figsize=(12, 8))  
sns.barplot(x=top_12.index, y=top_12.values)

for index, value in enumerate(top_12):
        plt.text(index, value , f'{value:.2f}%', ha='center')  # تحديد محاذاة النص وتدويره    
plt.xlabel('Black id')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 20 (Black id')
plt.xticks(rotation=45, ha='right')  

plt.tight_layout()
plt.show()

# %%
percentage_cg = (cg['opening_response'].value_counts() / len(cg)) * 100
top_12 = percentage_cg.nlargest(15)
top_12_new = top_12.drop('0', errors='ignore')

plt.figure(figsize=(11, 7))  
sns.barplot(x=top_12_new.index, y=top_12_new.values)

for index, value in enumerate(top_12_new):
        plt.text(index, value, f'{value:.2f}%', ha='center',va='bottom')  # تحديد محاذاة النص وتدويره    
plt.xlabel('Opening Response')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 15 Opening Response')

plt.tight_layout()
plt.show()

# %%
percentage_cg = (cg['opening_shortname'].value_counts() / len(cg)) * 100
top_12 = percentage_cg.nlargest(12)

plt.figure(figsize=(12, 8))  
sns.barplot(x=top_12.index, y=top_12.values)

for index, value in enumerate(top_12):
        plt.text(index, value , f'{value:.2f}%', ha='center')  # تحديد محاذاة النص وتدويره    
plt.xlabel('Opening shortname')
plt.ylabel('Percentage')
plt.title('Percentage Distribution of Top 12 Opening shortname')
plt.xticks(rotation=45, ha='right')  

plt.tight_layout()
plt.show()
